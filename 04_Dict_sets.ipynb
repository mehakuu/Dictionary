# %% [markdown]
# # dictonary

# %%
myDict = {
    "Fast": "In a Quick Manner",
    "Harry": "A Coder",
    "Marks": [1, 2, 5], #list inside a dict
    "anotherdict": {'harry': 'Player'} #dict inside a dict
}
type(myDict)
# Out:
# dict

# %%
myDict["Fast"]
# Out:
# 'In a Quick Manner'

# %%
#print(myDict['Fast'])
#print(myDict['Harry'])
#myDict['Marks'] = [45, 78]  #mutable dict
#print(myDict['Marks'])
#print(myDict['anotherdict'])
print(myDict['anotherdict']["harry"])
# Out:
# Player

# %%
myDict["Marks"]
# Out:
# [45, 78]

# %%
myDict["Marks"][1]
# Out:
# 78

# %%
# Dictionary Methods
#print(list(myDict.keys())) # Prints the keys of the dictionary
#print(myDict.values()) # Prints the values of the dictionary 
print(myDict.items()) # Prints the (key, value) for all contents of the dictionary
# Out:
# dict_items([('Fast', 'In a Quick Manner'), ('Harry', 'A Coder'), ('Marks', [45, 78]), ('anotherdict', {'harry': 'Player'})])

# %%
a = list(myDict.keys()) 
print(a)
# Out:
# ['Fast', 'Harry', 'Marks', 'anotherdict']

# %%
a[1:3]
# Out:
# ['Harry', 'Marks']

# %%
updateDict = {
    "Lovish": "Friend",
    "Divya": "Friend",
    "Shubham": "Friend",
    "harry": "A Dancer"
}

# %%
myDict.update(updateDict) # Updates the dictionary by adding key-value pairs from updateDict
print(myDict)
# Out:
# {'Fast': 'In a Quick Manner', 'Harry': 'A Coder', 'Marks': [45, 78], 'anotherdict': {'harry': 'Player'}, 'Lovish': 'Friend', 'Divya': 'Friend', 'Shubham': 'Friend', 'harry': 'A Dancer'}

# %%
print(myDict.get("harry")) # Prints value associated with key "harry"
print(myDict["harry"]) # Prints value associated with key "harry"
# Out:
# A Dancer
# A Dancer

# %%
# The difference between .get and [] sytax in Dictionaries?
#print(myDict.get("harry2")) # Returns None as harry2 is not present in the dictionary
print(myDict["harry2"]) # throws an error as harry2 is not present in the dictionary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-f02eab0f0291> in <module>
#       1 # The difference between .get and [] sytax in Dictionaries?
#       2 #print(myDict.get("harry2")) # Returns None as harry2 is not present in the dictionary
# ----> 3 print(myDict["harry2"]) # throws an error as harry2 is not present in the dictionary
#
# KeyError: 'harry2'

# %%
a = {1, 3, 4, 5, 1}
print(type(a))
print(a)
# Out:
# <class 'set'>
# {1, 3, 4, 5}

# %%
# Important: This syntax will create an empty dictionary and not an empty set
a = {}
print(type(a))

# An empty set can be created using the below syntax:
b = set()
print(type(b))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
# Creating an empty set
b = set()
print(type(b))
# Out:
# <class 'set'>

# %%
## Adding values to an empty set
b.add(4)

# %%
b
# Out:
# {4}

# %%
b.add(4)
b.add(5)
b.add(5) # Adding a value repeatedly does not changes a set
b.add((4, 5, 6))
print(b)
# Out:
# {(4, 5, 6), 4, 5}

# %%
## Accessing Elements
b.add({4:5}) # Cannot add list or dictionary to sets
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-e5141f0b6927> in <module>
#       1 ## Accessing Elements
# ----> 2 b.add({4:5}) # Cannot add list or dictionary to sets
#       3 print(b)
#
# TypeError: unhashable type: 'dict'

# %%
## Length of the Set
print(len(b)) # Prints the length of this set
# Out:
# 3

# %%
## Removal of an Item
#b.remove(5) # Removes 5 fromt set b
b.remove(15) # throws an error while trying to remove 15 (which is not present in the set)
print(b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-bf24899d1368> in <module>
#       1 ## Removal of an Item
#       2 #b.remove(5) # Removes 5 fromt set b
# ----> 3 b.remove(15) # throws an error while trying to remove 15 (which is not present in the set)
#       4 print(b)
#
# KeyError: 15

# %%
print(b.pop())
print(b)
# Out:
# (4, 5, 6)
# {4}
